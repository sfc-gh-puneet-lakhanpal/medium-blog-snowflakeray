# %%
import ray
import os
from starlette.requests import Request
from typing import List, Optional, Any
import torch
import shutil
import logging
import sys
import json
import time
from huggingface_hub.hf_api import HfFolder
import json
from typing import AsyncGenerator
from fastapi import BackgroundTasks
from starlette.requests import Request
from starlette.responses import StreamingResponse, Response
from vllm.engine.arg_utils import AsyncEngineArgs
from vllm.engine.async_llm_engine import AsyncLLMEngine
from vllm.sampling_params import SamplingParams
from vllm.logger import init_logger
from vllm.utils import random_uuid
from ray import serve
import vllm
vllm_logger = init_logger(__name__)
vllm_logger.setLevel(logging.DEBUG)

# %%
MODEL = "lmsys/vicuna-13b-v1.5-16k"

# %%
logger = logging.getLogger("ray.serve")
logger.setLevel(logging.DEBUG)

@serve.deployment(num_replicas=1, ray_actor_options={"resources": {"custom_llm_serving_label": 1}}, route_prefix="/llmapi")
class SnowflakeVLLMDeployment:
    def __init__(self, **kwargs):
        args = AsyncEngineArgs(**kwargs)
        self.engine = AsyncLLMEngine.from_engine_args(args)

    async def stream_results(self, results_generator) -> AsyncGenerator[bytes, None]:
        num_returned = 0
        async for request_output in results_generator:
            text_outputs = [output.text for output in request_output.outputs]
            assert len(text_outputs) == 1
            text_output = text_outputs[0][num_returned:]
            ret = {"text": text_output}
            yield (json.dumps(ret) + "\n").encode("utf-8")
            num_returned += len(text_output)

    async def may_abort_request(self, request_id) -> None:
        await self.engine.abort(request_id)

    async def __call__(self, request: Request) -> Response:
        request_dict = await request.json()
        prompt = request_dict.pop("prompt")
        stream = request_dict.pop("stream", False)
        sampling_params = SamplingParams(**request_dict)
        request_id = random_uuid()
        results_generator = self.engine.generate(prompt, sampling_params, request_id)
        if stream:
            background_tasks = BackgroundTasks()
            background_tasks.add_task(self.may_abort_request, request_id)
            return StreamingResponse(
                self.stream_results(results_generator), background=background_tasks
            )

        # Non-streaming case
        final_output = None
        async for request_output in results_generator:
            if await request.is_disconnected():
                # Abort the request if the client disconnects.
                await self.engine.abort(request_id)
                return Response(status_code=499)
            final_output = request_output

        assert final_output is not None
        #prompt = final_output.prompt
        #text_outputs = [prompt + output.text for output in final_output.outputs]
        text_outputs = [output.text for output in final_output.outputs]
        ret = {"text": text_outputs}
        return Response(content=json.dumps(ret))
# Out:
# DeprecationWarning: `route_prefix` in `@serve.deployment` has been deprecated. To specify a route prefix for an application, pass it into `serve.run` instead.

# %%
deployment = SnowflakeVLLMDeployment.bind(model=MODEL, tensor_parallel_size=8, seed=123)
ray.init(address="auto", runtime_env={"pip": ["flash-attn==2.4.2"]})
serve.run(target=deployment, name="llm")
# Out:
# 2024-04-18 05:20:10,917	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.244.31.9:6379...
# 2024-04-18 05:20:12,147	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at http://10.244.31.9:8265
# [2024-04-18 05:20:12,150 I 877 877] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (raylet) [2024-04-18 05:20:13,924 I 958 958] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (ProxyActor pid=997) INFO 2024-04-18 05:20:19,945 proxy 10.244.31.9 proxy.py:1143 - Proxy actor 28061d6e60351e0feb9de5a802000000 starting on node b3d8591b0a074a32350190f00903d159aa0ccf0c5ff8c3eb9c01662d.
# (raylet) [2024-04-18 05:20:17,892 I 997 997] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (ServeController pid=958) INFO 2024-04-18 05:20:20,322 controller 958 deployment_state.py:1547 - Deploying new version of deployment SnowflakeVLLMDeployment in application 'llm'. Setting initial target number of replicas to 1.
# (ServeController pid=958) INFO 2024-04-18 05:20:20,425 controller 958 deployment_state.py:1831 - Adding 1 replica to deployment SnowflakeVLLMDeployment in application 'llm'.
# (ProxyActor pid=997) INFO 2024-04-18 05:20:20,193 proxy 10.244.31.9 proxy.py:1357 - Starting HTTP server on node: b3d8591b0a074a32350190f00903d159aa0ccf0c5ff8c3eb9c01662d listening on port 8000
# (ProxyActor pid=997) INFO:     Started server process [997]
# (raylet, ip=10.244.29.9) [2024-04-18 05:20:20,790 I 519 519] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) SIGTERM handler is not set because current thread is not the main thread.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) Calling ray.init() again after it has already been called.
# (raylet, ip=10.244.29.9) [2024-04-18 05:20:26,575 I 593 593] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:20:27 llm_engine.py:75] Initializing an LLM engine (v0.4.0) with config: model='lmsys/vicuna-13b-v1.5-16k', tokenizer='lmsys/vicuna-13b-v1.5-16k', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=auto, tensor_parallel_size=8, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=123)
# (ProxyActor pid=593, ip=10.244.29.9) INFO 2024-04-18 05:20:27,686 proxy 10.244.29.9 proxy.py:1143 - Proxy actor 7e4d92bb5714be711ef0042102000000 starting on node e219648a2f442d57852464195933cd440000e47546ef89e83b32621a.
# (ProxyActor pid=593, ip=10.244.29.9) INFO 2024-04-18 05:20:27,691 proxy 10.244.29.9 proxy.py:1357 - Starting HTTP server on node: e219648a2f442d57852464195933cd440000e47546ef89e83b32621a listening on port 8000
# (ProxyActor pid=593, ip=10.244.29.9) INFO:     Started server process [593]
# (raylet, ip=10.244.30.9) [2024-04-18 05:20:33,187 I 629 629] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1 [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (raylet, ip=10.244.30.9) [2024-04-18 05:20:42,339 I 766 766] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1 [repeated 2x across cluster]
# (ServeController pid=958) WARNING 2024-04-18 05:20:50,467 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (raylet, ip=10.244.29.9) [2024-04-18 05:20:46,851 I 730 730] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (raylet, ip=10.244.29.9) [2024-04-18 05:20:51,424 I 797 797] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1
# (raylet, ip=10.244.29.9) [2024-04-18 05:21:00,576 I 934 934] logging.cc:230: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to -1 [repeated 2x across cluster]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:21:05 selector.py:16] Using FlashAttention backend.
# (RayWorkerVllm pid=797, ip=10.244.29.9) INFO 04-18 05:21:06 pynccl_utils.py:45] vLLM is using nccl==2.18.1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO NCCL_SOCKET_IFNAME set by environment to eth0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO Bootstrap : Using eth0:10.244.29.9<0>
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO NET/Plugin : Plugin load (libnccl-net.so) returned 2 : libnccl-net.so: cannot open shared object file: No such file or directory
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO NET/Plugin : No plugin found, using internal implementation
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO cudaDriverVersion 12010
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) NCCL version 2.18.1+cuda12.1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Failed to open libibverbs.so[.1]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO NET/Socket : Using [0]eth0:10.244.29.9<0>
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Using network Socket
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO NVLS multicast support is not available on dev 0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 00/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 01/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Trees [0] 5/1/-1->0->-1 [1] 5/-1/-1->0->1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P Chunksize set to 131072
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 00/0 : 4[1e0] -> 0[1b0] [receive] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 01/0 : 4[1e0] -> 0[1b0] [receive] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 00 : 0[1b0] -> 5[1c0] via SHM/direct/direct
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 01 : 0[1b0] -> 5[1c0] via SHM/direct/direct
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Connected all rings
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 00/0 : 0[1b0] -> 1[1b0] [send] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 01/0 : 0[1b0] -> 1[1b0] [send] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 00/0 : 1[1b0] -> 0[1b0] [receive] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO Channel 01/0 : 1[1b0] -> 0[1b0] [receive] via NET/Socket/0
# (RayWorkerVllm pid=698, ip=10.244.30.9) statefulset-0:698:851 [2] NCCL INFO Connected all trees
# (RayWorkerVllm pid=698, ip=10.244.30.9) statefulset-0:698:851 [2] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 512 | 512
# (RayWorkerVllm pid=698, ip=10.244.30.9) statefulset-0:698:851 [2] NCCL INFO 2 coll channels, 0 nvls channels, 2 p2p channels, 2 p2p channels per peer
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1019 [0] NCCL INFO comm 0x7f26db7fc8e0 rank 0 nranks 8 cudaDev 0 busId 1b0 commId 0xca55ce014de306e1 - Init COMPLETE
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO Channel 00/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:571 [0] NCCL INFO Channel 01/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) WARNING 04-18 05:21:07 custom_all_reduce.py:149] Cannot test GPU P2P because not all GPUs are visible to the current process. This might be the case if 'CUDA_VISIBLE_DEVICES' is set.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) WARNING 04-18 05:21:07 custom_all_reduce.py:45] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:21:08 weight_utils.py:177] Using model weights format ['*.bin']
# (ServeController pid=958) WARNING 2024-04-18 05:21:20,525 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=958) WARNING 2024-04-18 05:21:50,592 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (RayWorkerVllm pid=698, ip=10.244.30.9) INFO 04-18 05:22:17 model_runner.py:104] Loading model weights took 3.0467 GB
# (RayWorkerVllm pid=766, ip=10.244.30.9) INFO 04-18 05:21:05 selector.py:16] Using FlashAttention backend. [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) INFO 04-18 05:21:06 pynccl_utils.py:45] vLLM is using nccl==2.18.1 [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:850 [3] NCCL INFO NCCL_SOCKET_IFNAME set by environment to eth0 [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Bootstrap : Using eth0:10.244.30.9<0> [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO NET/Plugin : Plugin load (libnccl-net.so) returned 2 : libnccl-net.so: cannot open shared object file: No such file or directory [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO NET/Plugin : No plugin found, using internal implementation [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO cudaDriverVersion 12010 [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:850 [3] NCCL INFO Failed to open libibverbs.so[.1] [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:850 [3] NCCL INFO NET/Socket : Using [0]eth0:10.244.30.9<0> [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Using network Socket [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1. [repeated 812x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 2(=1d0) [repeated 452x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO NVLS multicast support is not available on dev 3 [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Trees [0] -1/-1/-1->4->3 [1] -1/-1/-1->4->3 [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO P2P Chunksize set to 131072 [repeated 15x across cluster]
# (RayWorkerVllm pid=562, ip=10.244.30.9) statefulset-0:562:562 [0] NCCL INFO Channel 01/0 : 0[1b0] -> 1[1b0] [receive] via NET/Socket/0 [repeated 12x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Channel 01 : 4[1e0] -> 3[1d0] via SHM/direct/direct [repeated 46x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO Connected all rings [repeated 15x across cluster]
# (RayWorkerVllm pid=562, ip=10.244.30.9) statefulset-0:562:562 [0] NCCL INFO Channel 01/0 : 1[1b0] -> 0[1b0] [send] via NET/Socket/0 [repeated 14x across cluster]
# (RayWorkerVllm pid=629, ip=10.244.30.9) statefulset-0:629:629 [1] NCCL INFO Connected all trees [repeated 15x across cluster]
# (RayWorkerVllm pid=629, ip=10.244.30.9) statefulset-0:629:629 [1] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 512 | 512 [repeated 15x across cluster]
# (RayWorkerVllm pid=629, ip=10.244.30.9) statefulset-0:629:629 [1] NCCL INFO 2 coll channels, 0 nvls channels, 2 p2p channels, 2 p2p channels per peer [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:766 [3] NCCL INFO comm 0xa15f560 rank 4 nranks 8 cudaDev 3 busId 1e0 commId 0x7d51a1ba241da663 - Init COMPLETE [repeated 15x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) WARNING 04-18 05:21:07 custom_all_reduce.py:149] Cannot test GPU P2P because not all GPUs are visible to the current process. This might be the case if 'CUDA_VISIBLE_DEVICES' is set. [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) WARNING 04-18 05:21:07 custom_all_reduce.py:45] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly. [repeated 7x across cluster]
# (RayWorkerVllm pid=934, ip=10.244.29.9) INFO 04-18 05:21:08 weight_utils.py:177] Using model weights format ['*.bin'] [repeated 7x across cluster]
# (ServeController pid=958) WARNING 2024-04-18 05:22:20,631 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=958) WARNING 2024-04-18 05:22:50,707 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=958) WARNING 2024-04-18 05:23:20,710 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (RayWorkerVllm pid=766, ip=10.244.30.9) INFO 04-18 05:23:25 model_runner.py:104] Loading model weights took 3.0467 GB
# (RayWorkerVllm pid=629, ip=10.244.30.9) INFO 04-18 05:23:25 model_runner.py:104] Loading model weights took 3.0467 GB
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:23:38 model_runner.py:104] Loading model weights took 3.0467 GB
# (RayWorkerVllm pid=865, ip=10.244.29.9) INFO 04-18 05:23:40 model_runner.py:104] Loading model weights took 3.0467 GB
# (ServeController pid=958) WARNING 2024-04-18 05:23:50,741 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=958) WARNING 2024-04-18 05:24:20,789 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (RayWorkerVllm pid=797, ip=10.244.29.9) INFO 04-18 05:24:50 model_runner.py:104] Loading model weights took 3.0467 GB [repeated 2x across cluster]
# (ServeController pid=958) WARNING 2024-04-18 05:24:50,888 controller 958 deployment_state.py:2169 - Deployment 'SnowflakeVLLMDeployment' in application 'llm' has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Using network Socket
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 0. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 0(=1b0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 3 and 2. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 3(=1e0) and dev 2(=1d0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 1 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 1(=1c0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 2 and 3. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 2(=1d0) and dev 3(=1e0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO NVLS multicast support is not available on dev 0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 00/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 01/02 :    0   5   6   7   1   2   3   4
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Trees [0] 5/1/-1->0->-1 [1] 5/-1/-1->0->1
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P Chunksize set to 131072
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 00/0 : 4[1e0] -> 0[1b0] [receive] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 01/0 : 4[1e0] -> 0[1b0] [receive] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 00 : 0[1b0] -> 5[1c0] via SHM/direct/direct
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0)
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 01 : 0[1b0] -> 5[1c0] via SHM/direct/direct
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Connected all rings
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 00/0 : 0[1b0] -> 1[1b0] [send] via NET/Socket/0
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO Channel 01/0 : 0[1b0] -> 1[1b0] [send] via NET/Socket/0
# (RayWorkerVllm pid=934, ip=10.244.29.9) statefulset-1:934:1088 [3] NCCL INFO Connected all trees
# (RayWorkerVllm pid=934, ip=10.244.29.9) statefulset-1:934:1088 [3] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 512 | 512
# (RayWorkerVllm pid=934, ip=10.244.29.9) statefulset-1:934:1088 [3] NCCL INFO 2 coll channels, 0 nvls channels, 2 p2p channels, 2 p2p channels per peer
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1085 [0] NCCL INFO comm 0x7f24dc889740 rank 0 nranks 8 cudaDev 0 busId 1b0 commId 0xb838348c697afde2 - Init COMPLETE
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:25:05 ray_gpu_executor.py:240] # GPU blocks: 10225, # CPU blocks: 2621
# (RayWorkerVllm pid=562, ip=10.244.30.9) INFO 04-18 05:24:52 model_runner.py:104] Loading model weights took 3.0467 GB
# (RayWorkerVllm pid=698, ip=10.244.30.9) statefulset-0:698:922 [2] NCCL INFO Using network Socket [repeated 7x across cluster]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1100 [0] NCCL INFO P2P is disabled between connected GPUs 0 and 1. You can repress this message with NCCL_IGNORE_DISABLED_P2P=1. [repeated 394x across cluster]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1100 [0] NCCL INFO Could not enable P2P between dev 0(=1b0) and dev 1(=1c0) [repeated 226x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:919 [3] NCCL INFO NVLS multicast support is not available on dev 3 [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:919 [3] NCCL INFO Trees [0] -1/-1/-1->4->3 [1] -1/-1/-1->4->3 [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:919 [3] NCCL INFO P2P Chunksize set to 131072 [repeated 7x across cluster]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) statefulset-1:519:1100 [0] NCCL INFO Channel 01/1 : 1[1b0] -> 0[1b0] [receive] via NET/Socket/0/Shared [repeated 14x across cluster]
# (RayWorkerVllm pid=934, ip=10.244.29.9) statefulset-1:934:1098 [3] NCCL INFO Channel 01 : 7[1e0] -> 0[1b0] via SHM/direct/direct [repeated 28x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:919 [3] NCCL INFO Connected all rings [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:932 [3] NCCL INFO Channel 01/1 : 4[1e0] -> 0[1b0] [send] via NET/Socket/0/Shared [repeated 14x across cluster]
# (RayWorkerVllm pid=562, ip=10.244.30.9) statefulset-0:562:921 [0] NCCL INFO Connected all trees [repeated 7x across cluster]
# (RayWorkerVllm pid=562, ip=10.244.30.9) statefulset-0:562:921 [0] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 512 | 512 [repeated 7x across cluster]
# (RayWorkerVllm pid=562, ip=10.244.30.9) statefulset-0:562:921 [0] NCCL INFO 2 coll channels, 0 nvls channels, 2 p2p channels, 2 p2p channels per peer [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) statefulset-0:766:919 [3] NCCL INFO comm 0x13f36050 rank 4 nranks 8 cudaDev 3 busId 1e0 commId 0xb838348c697afde2 - Init COMPLETE [repeated 7x across cluster]
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:25:07 model_runner.py:791] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# (ServeReplica:llm:SnowflakeVLLMDeployment pid=519, ip=10.244.29.9) INFO 04-18 05:25:07 model_runner.py:795] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# (RayWorkerVllm pid=797, ip=10.244.29.9) INFO 04-18 05:25:17 model_runner.py:867] Graph capturing finished in 10 secs.
# (RayWorkerVllm pid=766, ip=10.244.30.9) INFO 04-18 05:25:07 model_runner.py:791] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. [repeated 7x across cluster]
# (RayWorkerVllm pid=766, ip=10.244.30.9) INFO 04-18 05:25:07 model_runner.py:795] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage. [repeated 7x across cluster]
# 2024-04-18 05:25:17,623	INFO router.py:959 -- Using router <class 'ray.serve._private.router.PowerOfTwoChoicesReplicaScheduler'>.
# 2024-04-18 05:25:17,633	DEBUG long_poll.py:156 -- LongPollClient <ray.serve._private.long_poll.LongPollClient object at 0x7f4184254a00> received updates for keys: [(LongPollNamespace.RUNNING_REPLICAS, DeploymentID(name='SnowflakeVLLMDeployment', app='llm'))].
# 2024-04-18 05:25:17,634	INFO router.py:496 -- Got updated replicas for deployment 'SnowflakeVLLMDeployment' in application 'llm': {'llm#SnowflakeVLLMDeployment#JMXtMC'}.
# DeploymentHandle(deployment='SnowflakeVLLMDeployment')
# 2024-04-18 05:25:55,421	DEBUG long_poll.py:152 -- LongPollClient polling timed out. Retrying.
# 2024-04-18 05:26:53,873	DEBUG long_poll.py:152 -- LongPollClient polling timed out. Retrying.
# 2024-04-18 05:27:25,823	DEBUG long_poll.py:152 -- LongPollClient polling timed out. Retrying.
# 2024-04-18 05:28:09,373	DEBUG long_poll.py:152 -- LongPollClient polling timed out. Retrying.
# 2024-04-18 05:28:59,316	DEBUG long_poll.py:152 -- LongPollClient polling timed out. Retrying.
